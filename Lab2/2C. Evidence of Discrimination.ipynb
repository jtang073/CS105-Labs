# %% [markdown]
# # Evidence of Discrimination?
#
# The Department of Developmental Services (DDS) in California is responsible for allocating funds to support over 250,000 developmentally-disabled residents. The data set `ca_dds_expenditures.csv` contains data about 1,000 of these residents. The data comes from a discrimination lawsuit which alleged that California's Department of Developmental Services (DDS) privileged white (non-Hispanic) residents over Hispanic residents in allocating funds. We will focus on comparing the allocation of funds (i.e., expenditures) for these two ethnicities only, although there are other ethnicities in this data set.
#
# There are 6 variables in this data set:
#
# - Id:  5-digit, unique identification code for each consumer (similar to a social security number and used for identification purposes)
# - Age Cohort:  Binned age variable represented as six age cohorts (0-5, 6-12, 13-17, 18-21, 22-50, and 51+)
# - Age:  Unbinned age variable
# - Gender:  Male or Female
# - Expenditures:  Dollar amount of annual expenditures spent on each consumer
# - Ethnicity:  Eight ethnic groups (American Indian, Asian, Black, Hispanic, Multi-race, Native Hawaiian, Other, and White non-Hispanic)

# %% [markdown]
# # Question 1
#
# Read in the data set. Make a graphic that compares the _average_ expenditures by the DDS on Hispanic residents and white (non-Hispanic) residents. Comment on what you see.

# %%
# YOUR CODE HERE -- Done
import pandas as pd
df = pd.read_csv("ca_dds_expenditures.csv")

# %matplotlib inline
dfdf = df.loc[df.Ethnicity == "Hispanic"]
dsds = df.loc[df.Ethnicity == "White not Hispanic"]
dfdf = dfdf.append(dsds)
dfdf.groupby("Ethnicity")["Expenditures"].mean().plot.bar()

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
# It seems that the average expenditures of Hispanics are about half of those of the White (non-Hispanic) residents. This clearly depicts that there is some sort of unfairness within the residents that relates to race.

# %% [markdown]
# # Question 2
#
# Now, calculate the average expenditures by ethnicity and age cohort. Make a graphic that compares the average expenditure on Hispanic residents and white (non-Hispanic) residents, _within each age cohort_.
#
# Comment on what you see. How do these results appear to contradict the results you obtained in Question 1?

# %%
# YOUR CODE HERE -- Done
import numpy as np
# %matplotlib inline
table = pd.pivot_table(dfdf, values = {"Expenditures"}, index = {"Age Cohort"}, columns = {"Ethnicity"}, aggfunc=np.mean)
table.plot.bar()

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
# When looking at the graph above, it seems as if the Hispanic and the White (non-Hispanic) follow the same trend in each age cohort. In fact, some expenditures are even higher than those of white. These results defintely contradicts what was shown in question 1 and makes them seem as if they are similar to each other. In this case, more data was collected from White (non-Hispanic) in the 51+ age cohort range which inevitably will result in a higher overall average than those of other ethnicity even though the graph above contradicts the average.

# %% [markdown]
# # Question 3
#
# Can you explain the discrepancy between the two analyses you conducted above (i.e., Questions 1 and 2)? Try to tell a complete story that interweaves tables, graphics, and explanation.
#
# _Hint:_ You might want to consider looking at:
#
# - the distributions of ages of Hispanics and whites
# - the average expenditure as a function of age

# %%
# YOUR CODE HERE (although you may want to add more code cells) -- Done
# Take from lab 1B
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
x = df.iloc[:,[0,1,2,3,4,5]]
a = scatter_matrix(x, alpha=0.05, figsize=(5,5), diagonal='hist')
plt.show()

# %%
# YOUR CODE HERE (although you may want to add more code cells) -- Done
print(df.Ethnicity.value_counts())
print(df["Age Cohort"].value_counts())
# Out:
# White not Hispanic    401
# Hispanic              376
# Asian                 129
# Black                  59
# Multi Race             26
# American Indian         4
# Native Hawaiian         3
# Other                   2
# Name: Ethnicity, dtype: int64
# 22 to 50    226
# 13 to 17    212
# 18 to 21    199
# 6 to 12     175
# 51+         106
# 0 to 5       82
# Name: Age Cohort, dtype: int64

# %% [markdown]
# **YOUR EXPLANATION HERE (although you may want to add more markdown cells)**
#
# When looking at the graphs in the beginning of Question 3, you can see that there is somewhat a positive correlation between age and expenditures. In other words, as age increase, so does the average expenditure (Despite differences in ethnicity). However, you can obtain errors or false information when you look at question 1 because it shows a higher average for different ethnicity because of how poorly the data was gathered. As you can see above, the amount of data gathered between each ethnicity AND age cohort varies differently. These are the reasons why data can be skewed and does not tell you the whole story behind the dataset.

# %% [markdown]
# ## Submission Instructions
#
# Once you are finished, follow these steps:
#
# 1. Restart the kernel and re-run this notebook from beginning to end by going to `Kernel > Restart Kernel and Run All Cells`.
#
# 2. If this process stops halfway through, that means there was an error. Correct the error and repeat Step 1 until the notebook runs from beginning to end.
#
# 3. Double check that there is a number next to each code cell and that these numbers are in order.
#
# Then, submit your lab as follows: Upload notebook (ipynb) iLearn.
